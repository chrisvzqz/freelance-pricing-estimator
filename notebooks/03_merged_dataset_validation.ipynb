# %%
import pandas as pd

# %%
df = pd.read_json("../data/raw/projects_merged.jsonl", lines=True)

# %%
df.head()
# Out:
#                                                title  \
# 0  Implementador de Crm/Whatsapp Api con Automati...
# 1  Automatización de Facturas con Ocr, Zapier e I...
# 2  Desarrollador Node.js / Sqlite para Proyecto C...
# 3  Desarrollador Wordpress + Elementor Pro para L...
# 4  Especialista Itil para Diseño e Implementación...
#
#                                          description  budget_min  budget_max  \
# 0  Se busca un implementador freelance con experi...       250.0       500.0
# 1  Se busca un programador experto para diseñar e...       500.0      1000.0
# 2  Buscamos un programador backend con perfil Jun...       100.0       250.0
# 3  Busco desarrollador con experiencia comprobabl...       100.0       250.0
# 4  Actualmente me desempeño como Jefe de Servicio...         NaN        15.0
#
#    budget_type                                             skills  \
# 0  fixed_price  [CRM, API, Facebook, Scripts & Utilities, Data...
# 1  fixed_price  [SQL, Database, ERP, API, System Analysis, Mod...
# 2  fixed_price          [Node.js, Express.js, SQL, Database, API]
# 3  fixed_price      [WordPress, HTML, CSS, Responsive Web Design]
# 4       hourly  [Informática, Technical Support, System Analys...
#
#                     category                  subcategory  \
# 0  Programación y Tecnología  Tiendas Online (e-commerce)
# 1  Programación y Tecnología             Programación Web
# 2  Programación y Tecnología             Programación Web
# 3  Programación y Tecnología             Programación Web
# 4  Programación y Tecnología                        Otros
#
#                                          project_url platform currency
# 0  https://www.workana.com/job/implementador-de-c...  Workana      USD
# 1  https://www.workana.com/job/automatizacion-de-...  Workana      USD
# 2  https://www.workana.com/job/desarrollador-node...  Workana      USD
# 3  https://www.workana.com/job/desarrollador-word...  Workana      USD
# 4  https://www.workana.com/job/especialista-itil-...  Workana      USD

# %%
df.tail()
# Out:
#                                      title  \
# 4718   Hebrew Translation Quality Reviewer
# 4719         Logo, Copywriting & AI Poster
# 4720  Outdoor Ultrasonic Vehicle Detection
# 4721                 Speech Recording Task
# 4722          10 Virtual Assistants Needed
#
#                                             description  budget_min  \
# 4718  I have a year-long project that needs a sharp ...         8.0
# 4719  Saya mencari seorang kreatif yang bisa mengeks...         8.0
# 4720  I need assistance in developing electronic for...        25.0
# 4721  I need native-sounding adults (25 years or old...       100.0
# 4722  I have a heavy workload managing emails and ch...       250.0
#
#       budget_max  budget_type  \
# 4718        15.0       hourly
# 4719        15.0       hourly
# 4720        50.0       hourly
# 4721       400.0       hourly
# 4722       750.0  fixed_price
#
#                                                  skills  \
# 4718  [Machine Translation, Language Tutoring, Editi...
# 4719  [Copywriting, Adobe Illustrator, Adobe Photosh...
# 4720  [Object Detection, Embedded Systems, Electroni...
# 4721  [Voice Over, Speech Synthesis, Voice Acting, A...
# 4722  [Email Handling, Chat Operation, Virtual Assis...
#
#                      category          subcategory  \
# 4718  Artificial Intelligence  Machine Translation
# 4719  Artificial Intelligence          Copywriting
# 4720  Artificial Intelligence     Object Detection
# 4721  Artificial Intelligence           Voice Over
# 4722  Artificial Intelligence       Email Handling
#
#                                             project_url    platform currency
# 4718  https://www.freelancer.com/projects/machine-tr...  Freelancer      USD
# 4719  https://www.freelancer.com/projects/copywritin...  Freelancer      USD
# 4720  https://www.freelancer.com/projects/object-det...  Freelancer      USD
# 4721  https://www.freelancer.com/projects/voice-over...  Freelancer      INR
# 4722  https://www.freelancer.com/projects/email-hand...  Freelancer      USD

# %% [markdown]
# ## 1. Dataset Overview

# %%
print(f"Total projects: {df.shape[0]}")
# Out:
# Total projects: 4723

# %%
print(f"Workana projects: {df.loc[df['platform'] == 'Workana'].shape[0]}")
# Out:
# Workana projects: 351

# %%
print(f"Freelancer projects: {df.loc[df['platform'] == 'Freelancer'].shape[0]}")
# Out:
# Freelancer projects: 4372

# %%
print(f"Percentage of Workana projects: {df.loc[df['platform'] == 'Workana'].shape[0] / df.shape[0] * 100:.2f}%")
print(f"Percentage of Freelancer projects: {df.loc[df['platform'] == 'Freelancer'].shape[0] / df.shape[0] * 100:.2f}%")
# Out:
# Percentage of Workana projects: 7.43%
# Percentage of Freelancer projects: 92.57%
