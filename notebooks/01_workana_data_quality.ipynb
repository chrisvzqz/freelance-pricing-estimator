# %%
import pandas as pd

# %%
df = pd.read_json("../data/raw/projects_workana.json")

# %%
df.tail()
# Out:
#                                                  title  \
# 347  Adaptación de Identidad Visual y Configuración...
# 348  Desarrollo e Implementación de Sistema de Resp...
# 349  Auditoría Integral de Seguridad y Calidad de C...
# 350  Configuración y Capacitación para Impresión Au...
# 351  Creación de Sitio Web en Wordpress con Enfoque...
#
#                                            description  budget_min  \
# 347  Se busca un profesional para realizar ajustes ...         NaN
# 348  Se busca un profesional o equipo para desarrol...       500.0
# 349  Una prestigiosa empresa de movilización en Ecu...      1000.0
# 350  Se requiere un profesional para configurar un ...        50.0
# 351  Busco un profesional o agencia con experiencia...       100.0
#
#      budget_max  budget_type  \
# 347        50.0  fixed_price
# 348      1000.0  fixed_price
# 349      3000.0  fixed_price
# 350       100.0  fixed_price
# 351       250.0  fixed_price
#
# ...

# %%
df.loc[df['budget_max'].isna() & (df['budget_type'] == 'fixed_price')].head()
# Out:
#                                                 title  \
# 9   Profesional de Ti con Experiencia Integral par...
# 11  Desarrollo de Power App para Gestión de Pedido...
# 40  Desarrollo Full-Stack de Sistema de Salud Digi...
# 53  Desarrollo de Aplicación Móvil Saas Multiplata...
# 72  Desarrollo y Estrategia de E-commerce para Pro...
#
#                                           description  budget_min  budget_max  \
# 9   Estamos buscando un profesional de TI altament...      3000.0         NaN
# 11  Se requiere el desarrollo de una Power App per...      3000.0         NaN
# 40  Se busca un desarrollador o equipo full-stack ...      3000.0         NaN
# 53  Se busca un desarrollador o equipo para crear ...      3000.0         NaN
# 72  Se busca un profesional o equipo para desarrol...      3000.0         NaN
#
#     budget_type                                             skills  \
# 9   fixed_price  [Technical Support, System Analysis, Software ...
# ...

# %%
print(df.loc[df['budget_max'].isna() & (df['budget_type'] == 'fixed_price')].shape[0])
# Out:
# 25

# %%
df.loc[df['budget_max'].isna() & (df['budget_type'] == 'hourly')].head()
# Out:
#                                                 title  \
# 38  Soporte Técnico Especializado en Shopify para ...
# 59  Experto en Automatización e Implementación de ...
# 74  Estrategia Integral para Escalar y Rentabiliza...
# 84  Migración Técnica de Wpbakery a Gutenberg en W...
# 97  Desarrollo de Aplicación Móvil Nativa para Sis...
#
#                                           description  budget_min  budget_max  \
# 38  Busco un soporte técnico freelance para el rel...        45.0         NaN
# 59  Buscamos un profesional con experiencia en aut...        45.0         NaN
# 74  Busco un profesional con experiencia en e-comm...        45.0         NaN
# 84  Hola. Busco un desarrollador WordPress/WooComm...        45.0         NaN
# 97  Se busca un equipo o desarrollador con experie...        45.0         NaN
#
#    budget_type                                             skills  \
# 38      hourly  [Shopify, HTML, CSS, JavaScript, Tiendas Onlin...
# ...

# %%
print(df.loc[df['budget_max'].isna() & (df['budget_type'] == 'hourly')].shape[0])
# Out:
# 14

# %%
df.loc[df['budget_min'].isna() & (df['budget_type'] == 'fixed_price')].head()
# Out:
#                                                  title  \
# 68   Desarrollo de Juego de Terror 3d en Unity para...
# 90   Ingeniero de Sistemas para Modificación de Res...
# 133  Desarrollo de Plataforma Web para Venta de Cla...
# 154  Godot Implementación de Mecánica de Bate con F...
# 182  Análisis Exhaustivo y Sugerencias de Mejora pa...
#
#                                            description  budget_min  \
# 68   Se busca un desarrollador de juegos experiment...         NaN
# 90   Se busca un ingeniero en sistemas con experien...         NaN
# 133  Se requiere el desarrollo de una página web co...         NaN
# 154  Se busca un desarrollador para implementar una...         NaN
# 182  Se busca un profesional para realizar un análi...         NaN
#
#      budget_max  budget_type  \
# 68         50.0  fixed_price
# 90         50.0  fixed_price
# 133        50.0  fixed_price
# 154        50.0  fixed_price
# 182        50.0  fixed_price
#
# ...

# %%
df.loc[df['budget_min'].isna() & (df['budget_type'] == 'fixed_price')].shape[0]
# Out:
# 13

# %%
df.loc[df['budget_min'].isna() & (df['budget_type'] == 'hourly')].head()
# Out:
#                                                 title  \
# 4   Especialista Itil para Diseño e Implementación...
# 22  Ingeniero Qa Senior para Aplicación Social Móv...
# 30  Consultor Freelancer Senior en Business Intell...
# 69  Desarrollo de Sistema Web para Búsqueda y Encu...
# 76        Desarrollo de Página Web Informativa en Php
#
#                                           description  budget_min  budget_max  \
# 4   Actualmente me desempeño como Jefe de Servicio...         NaN        15.0
# 22  YOIN es una aplicación social/de comunidad (iO...         NaN        15.0
# 30  Buscamos un consultor freelance de habla hispa...         NaN        15.0
# 69  Se requiere el desarrollo de un sistema web co...         NaN        15.0
# 76  Se busca un desarrollador web para la creación...         NaN        15.0
#
#    budget_type                                             skills  \
# 4       hourly  [Informática, Technical Support, System Analys...
# ...

# %%
df.loc[df['budget_min'].isna() & (df['budget_type'] == 'hourly')].shape[0]
# Out:
# 13

# %%
df.loc[df['budget_min'].isna()].shape[0]
# Out:
# 26

# %%
df.loc[df['category'].isna()]
# Out:
#                                                  title  \
# 115  Gestionar redes sociales  y campaña de publici...
#
#                                            description  budget_min  \
# 115  Buscamos personas  sepa gestionar redes social...        50.0
#
#      budget_max  budget_type skills category subcategory scope_project  \
# 115       100.0  fixed_price  [API]      NaN         NaN           NaN
#
#                                            project_url platform
# 115  https://www.workana.com/job/gestionar-redes-so...  Workana

# %%
df.loc[df['scope_project'].isna()]
# Out:
#                                                  title  \
# 4    Especialista Itil para Diseño e Implementación...
# 6    Experto Senior en Automatización Avanzada de K...
# 8    Desarrollo de Chatbot con Inteligencia Artific...
# 9    Profesional de Ti con Experiencia Integral par...
# 15   Experto en N8n y Agentes Ia para Desarrollo de...
# ..                                                 ...
# 331  Desarrollo de Chatbot para Whatsapp y Gestión ...
# 341  Desarrollo e Implementación de Chatbot con Ia ...
# 343  Desarrollo de Generador de Modelos 3d con Ia a...
# 344  Profesional Experto en Power Bi para Migración...
# 348  Desarrollo e Implementación de Sistema de Resp...
#
#                                            description  budget_min  \
# 4    Actualmente me desempeño como Jefe de Servicio...         NaN
# 6    Buscamos un experto senior en automatización d...       250.0
# 8    Se busca un desarrollador o equipo con experie...      1000.0
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Automatización de Facturas con Ocr, Zapier e Integración Sql Erp Sade para Despacho Contable     2
# Implementador de Crm/Whatsapp Api con Automatizaciones Comerciales                               1
# Desarrollador Node.js / Sqlite para Proyecto Corto de Api Backend                                1
# Desarrollador Wordpress + Elementor Pro para Landing Responsive + Whatsapp (Solo experiencia)    1
# Especialista Itil para Diseño e Implementación de Plan de Comunicación en Servicios Ti           1
#                                                                                                 ..
# Adaptación de Identidad Visual y Configuración de Wordpress con Tutor Lms                        1
# Desarrollo e Implementación de Sistema de Respuestas Automáticas con Ia para Whatsapp            1
# Auditoría Integral de Seguridad y Calidad de Código                                              1
# ...

# %%
df.loc[df['title'] == 'Automatización de Facturas con Ocr, Zapier e Integración Sql Erp Sade para Despacho Contable', 'project_url'].value_counts()
# Out:
# project_url
# https://www.workana.com/job/automatizacion-de-facturas-con-ocr-zapier-e-integracion-sql-erp-sade-para-despacho-contable    2
# Name: count, dtype: int64

# %%
df.loc[df['title'] == 'Automatización de Facturas con Ocr, Zapier e Integración Sql Erp Sade para Despacho Contable']
# Out:
#                                                 title  \
# 1   Automatización de Facturas con Ocr, Zapier e I...
# 41  Automatización de Facturas con Ocr, Zapier e I...
#
#                                           description  budget_min  budget_max  \
# 1   Se busca un programador experto para diseñar e...       500.0      1000.0
# 41  Se busca un programador experto para diseñar e...       500.0      1000.0
#
#     budget_type                                             skills  \
# 1   fixed_price  [SQL, Database, ERP, API, System Analysis, Mod...
# 41  fixed_price  [SQL, Database, ERP, API, System Analysis, Mod...
#
#                      category       subcategory  \
# 1   Programación y Tecnología  Programación Web
# 41  Programación y Tecnología  Programación Web
#
#                          scope_project  \
# 1   Crear un nuevo sitio personalizado
# 41  Crear un nuevo sitio personalizado
#
#                                           project_url platform
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          352 non-null    str
#  1   description    352 non-null    str
#  2   budget_min     326 non-null    float64
#  3   budget_max     313 non-null    float64
#  4   budget_type    352 non-null    str
#  5   skills         352 non-null    object
#  6   category       351 non-null    str
#  7   subcategory    351 non-null    str
#  8   scope_project  275 non-null    str
#  9   project_url    352 non-null    str
#  10  platform       352 non-null    str
# dtypes: float64(2), object(1), str(8)
# memory usage: 30.4+ KB

# %%
df.describe()
# Out:
#         budget_min   budget_max
# count   326.000000   313.000000
# mean    722.806748  1417.284345
# std     765.910432  1291.954073
# min      15.000000    15.000000
# 25%     100.000000   250.000000
# 50%     500.000000  1000.000000
# 75%    1000.000000  3000.000000
# max    3000.000000  3000.000000

# %%
df.isna().sum()
# Out:
# title             0
# description       0
# budget_min       26
# budget_max       39
# budget_type       0
# skills            0
# category          1
# subcategory       1
# scope_project    77
# project_url       0
# platform          0
# dtype: int64

# %%
df.loc[df["project_url"].duplicated()]
# Out:
#                                                 title  \
# 41  Automatización de Facturas con Ocr, Zapier e I...
#
#                                           description  budget_min  budget_max  \
# 41  Se busca un programador experto para diseñar e...       500.0      1000.0
#
#     budget_type                                             skills  \
# 41  fixed_price  [SQL, Database, ERP, API, System Analysis, Mod...
#
#                      category       subcategory  \
# 41  Programación y Tecnología  Programación Web
#
#                          scope_project  \
# 41  Crear un nuevo sitio personalizado
#
#                                           project_url platform
# 41  https://www.workana.com/job/automatizacion-de-...  Workana

# %%
df['budget_type'].value_counts()
# Out:
# budget_type
# fixed_price    308
# hourly          44
# Name: count, dtype: int64

# %%
df["skills"].apply(len).describe()
# Out:
# count    352.000000
# mean       7.193182
# std        3.138250
# min        1.000000
# 25%        5.000000
# 50%        7.000000
# 75%        9.000000
# max       23.000000
# Name: skills, dtype: float64

# %%
df.loc[df["skills"].apply(len) == 1].shape[0]
# Out:
# 3

# %%
df.loc[df["skills"].apply(len) == 23].shape[0]
# Out:
# 1

# %%
print("Rows:", len(df))
print("Unique URLs:", df['project_url'].nunique())
print("Duplicate URLs:", df['project_url'].duplicated().sum())

print(f"\n{df["budget_type"].value_counts()}")

print("\nMissing Values")
print(df.isna().sum())
# Out:
# Rows: 352
# Unique URLs: 351
# Duplicate URLs: 1
#
# budget_type
# fixed_price    308
# hourly          44
# Name: count, dtype: int64
#
# Missing Values
# title             0
# description       0
# budget_min       26
# budget_max       39
# budget_type       0
# skills            0
# category          1
# subcategory       1
# scope_project    77
# project_url       0
# platform          0
# dtype: int64

# %%
df['subcategory'].value_counts()
# Out:
# subcategory
# Programación Web                              158
# Inteligencia Artificial                        50
# Tiendas Online (e-commerce)                    47
# Programación de Apps. Android, iOS y otros     40
# Aplicaciones de escritorio                     19
# Otros                                          16
# Wordpress                                      10
# Data Science                                    9
# Diseño Web                                      2
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Programación y Tecnología    351
# Name: count, dtype: int64

# %%
df
# Out:
#                                                  title  \
# 0    Implementador de Crm/Whatsapp Api con Automati...
# 1    Automatización de Facturas con Ocr, Zapier e I...
# 2    Desarrollador Node.js / Sqlite para Proyecto C...
# 3    Desarrollador Wordpress + Elementor Pro para L...
# 4    Especialista Itil para Diseño e Implementación...
# ..                                                 ...
# 347  Adaptación de Identidad Visual y Configuración...
# 348  Desarrollo e Implementación de Sistema de Resp...
# 349  Auditoría Integral de Seguridad y Calidad de C...
# 350  Configuración y Capacitación para Impresión Au...
# 351  Creación de Sitio Web en Wordpress con Enfoque...
#
#                                            description  budget_min  \
# 0    Se busca un implementador freelance con experi...       250.0
# 1    Se busca un programador experto para diseñar e...       500.0
# 2    Buscamos un programador backend con perfil Jun...       100.0
# ...

# %%
df.loc[df['project_url'].duplicated(),'project_url']
# Out:
# 41    https://www.workana.com/job/automatizacion-de-...
# Name: project_url, dtype: str

# %%
df = df.drop_duplicates(subset=['project_url'], keep='first')

# %%
df.loc[df['project_url'].duplicated(),'project_url']
# Out:
# Series([], Name: project_url, dtype: str)

# %%
df = df.drop('scope_project', axis=1)

# %%
df
# Out:
#                                                  title  \
# 0    Implementador de Crm/Whatsapp Api con Automati...
# 1    Automatización de Facturas con Ocr, Zapier e I...
# 2    Desarrollador Node.js / Sqlite para Proyecto C...
# 3    Desarrollador Wordpress + Elementor Pro para L...
# 4    Especialista Itil para Diseño e Implementación...
# ..                                                 ...
# 347  Adaptación de Identidad Visual y Configuración...
# 348  Desarrollo e Implementación de Sistema de Resp...
# 349  Auditoría Integral de Seguridad y Calidad de C...
# 350  Configuración y Capacitación para Impresión Au...
# 351  Creación de Sitio Web en Wordpress con Enfoque...
#
#                                            description  budget_min  \
# 0    Se busca un implementador freelance con experi...       250.0
# 1    Se busca un programador experto para diseñar e...       500.0
# 2    Buscamos un programador backend con perfil Jun...       100.0
# ...

# %%
df['currency'] = 'USD'

# %%
df
# Out:
#                                                  title  \
# 0    Implementador de Crm/Whatsapp Api con Automati...
# 1    Automatización de Facturas con Ocr, Zapier e I...
# 2    Desarrollador Node.js / Sqlite para Proyecto C...
# 3    Desarrollador Wordpress + Elementor Pro para L...
# 4    Especialista Itil para Diseño e Implementación...
# ..                                                 ...
# 347  Adaptación de Identidad Visual y Configuración...
# 348  Desarrollo e Implementación de Sistema de Resp...
# 349  Auditoría Integral de Seguridad y Calidad de C...
# 350  Configuración y Capacitación para Impresión Au...
# 351  Creación de Sitio Web en Wordpress con Enfoque...
#
#                                            description  budget_min  \
# 0    Se busca un implementador freelance con experi...       250.0
# 1    Se busca un programador experto para diseñar e...       500.0
# 2    Buscamos un programador backend con perfil Jun...       100.0
# ...
