# %%
import pandas as pd

# %%
df = pd.read_json('../data/raw/projects_freelancer.jsonl', lines=True)

# %%
df.head()
# Out:
#                                                title  \
# 0                 All-in-One Travel Booking Platform
# 1  Power Automate Consultant for Business Automat...
# 2          Employee Hours/ Holiday/ Sickness tracker
# 3                      Custom Image Puzzle Generator
# 4                        C# Real-Time Automation App
#
#                                          description  budget_min  budget_max  \
# 0  The platform will include:\n• Hotel booking\n•...         750      1250.0
# 1  About the role\nWe're a multi-location automot...         750      1500.0
# 2  I'm looking for a Windows desktop application ...          20       250.0
# 3  I need a standalone Windows application that t...          10       100.0
# 4  I need a Windows desktop application written i...        1500     12500.0
#
#   currency  budget_type                                             skills  \
# 0      INR       hourly  [.NET, Website Design, Inventory Management, H...
# 1      USD  fixed_price  [Power Automate, Microsoft 365, Data Managemen...
# 2      GBP  fixed_price  [Desktop Application, Alerting, Software Devel...
# 3      USD  fixed_price  [SVG, Software Development, Desktop Applicatio...
# 4      INR  fixed_price  [REST API, JSON, Visual Studio, Software Devel...
#
#                                          project_url                 category  \
# 0  https://www.freelancer.com/projects/dot-net/al...  Websites, IT & Software
# 1  https://www.freelancer.com/projects/power-auto...  Websites, IT & Software
# 2  https://www.freelancer.com/projects/desktop-ap...  Websites, IT & Software
# 3  https://www.freelancer.com/projects/svg/custom...  Websites, IT & Software
# 4  https://www.freelancer.com/projects/rest-api/r...  Websites, IT & Software
#
#            subcategory    platform
# 0                 .NET  Freelancer
# 1       Power Automate  Freelancer
# 2  Desktop Application  Freelancer
# 3                  SVG  Freelancer
# 4             REST API  Freelancer

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4372 entries, 0 to 4371
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        4372 non-null   str
#  1   description  4372 non-null   str
#  2   budget_min   4372 non-null   int64
#  3   budget_max   4278 non-null   float64
#  4   currency     4372 non-null   str
#  5   budget_type  4372 non-null   str
#  6   skills       4372 non-null   object
#  7   project_url  4372 non-null   str
#  8   category     4372 non-null   str
#  9   subcategory  4372 non-null   str
#  10  platform     4372 non-null   str
# dtypes: float64(1), int64(1), object(1), str(8)
# memory usage: 375.8+ KB

# %%
df.isna().sum()
# Out:
# title           0
# description     0
# budget_min      0
# budget_max     94
# currency        0
# budget_type     0
# skills          0
# project_url     0
# category        0
# subcategory     0
# platform        0
# dtype: int64

# %%
df.loc[df['budget_max'].isna()]
# Out:
#                                                   title  \
# 35                    Email Marketing Copywriter Needed
# 113          Corporate Slide Deck Revamp with Animation
# 806          Long-Term Technical Partner Wanted (EU/US)
# 812                  Software Product Manager & Analyst
# 817                     Custom Dynamics 365 CRM Builder
# ...                                                 ...
# 4240  Audio Transcriptionist Wanted | Arabic - Mixed...
# 4241  Audio Transcriptionist Wanted | Arabic - Saudi...
# 4242  Audio Transcriptionist Wanted | Arabic - Egypt...
# 4243  Audio Transcriptionist Wanted | Spanish - Spai...
# 4244  Audio Transcriptionist Wanted | Portuguese - B...
#
#                                             description  budget_min  \
# 35    I’m planning a fresh sequence of marketing ema...          50
# 113   I'm seeking a skilled designer to enhance my s...          36
# 806   Looking for a Long-Term Technical Partner (Eur...          50
# 812   I’m bringing a new technology-driven software ...        2500
# 817   I am rolling out Microsoft Dynamics 365 to cov...          50
# ...                                                 ...         ...
# 4240  We are looking for a freelance audio transcrip...          71
# 4241  We are looking for a freelance audio transcrip...          78
# 4242  We are looking for a freelance audio transcrip...          43
# 4243  We are looking for a freelance audio transcrip...          78
# 4244  We are looking for a freelance audio transcrip...          32
#
#       budget_max currency budget_type  \
# 35           NaN      USD      hourly
# 113          NaN      GBP      hourly
# 806          NaN      USD      hourly
# 812          NaN      INR      hourly
# 817          NaN      USD      hourly
# ...          ...      ...         ...
# 4240         NaN      USD      hourly
# 4241         NaN      USD      hourly
# 4242         NaN      USD      hourly
# 4243         NaN      USD      hourly
# 4244         NaN      USD      hourly
#
#                                                  skills  \
# 35    [A/B Testing, Article Writing, Content Writing...
# 113   [Adobe Creative Cloud, Adobe Animate, Visual D...
# 806   [Software Development, Cloud Computing, Backen...
# 812   [Product Management, Agile Development, Softwa...
# 817   [API, CRM, Microsoft, Data Integration, HTML, ...
# ...                                                 ...
# 4240  [Arabic Translator, AI (Artificial Intelligenc...
# 4241  [Arabic Translator, AI (Artificial Intelligenc...
# 4242  [Arabic Translator, AI (Artificial Intelligenc...
# 4243  [Spanish Translator, AI (Artificial Intelligen...
# 4244  [Portuguese Translator, AI (Artificial Intelli...
#
#                                             project_url  \
# 35    https://www.freelancer.com/projects/ab-testing...
# 113   https://www.freelancer.com/projects/adobe-crea...
# 806   https://www.freelancer.com/projects/software-d...
# 812   https://www.freelancer.com/projects/product-ma...
# 817   https://www.freelancer.com/projects/api/custom...
# ...                                                 ...
# 4240  https://www.freelancer.com/projects/arabic-tra...
# 4241  https://www.freelancer.com/projects/arabic-tra...
# 4242  https://www.freelancer.com/projects/arabic-tra...
# 4243  https://www.freelancer.com/projects/spanish-tr...
# 4244  https://www.freelancer.com/projects/portuguese...
#
#                      category            subcategory    platform
# 35    Websites, IT & Software            A/B Testing  Freelancer
# 113   Websites, IT & Software   Adobe Creative Cloud  Freelancer
# 806   Websites, IT & Software   Software Development  Freelancer
# 812   Websites, IT & Software     Product Management  Freelancer
# 817   Websites, IT & Software                    API  Freelancer
# ...                       ...                    ...         ...
# 4240  Artificial Intelligence      Arabic Translator  Freelancer
# 4241  Artificial Intelligence      Arabic Translator  Freelancer
# 4242  Artificial Intelligence      Arabic Translator  Freelancer
# 4243  Artificial Intelligence     Spanish Translator  Freelancer
# 4244  Artificial Intelligence  Portuguese Translator  Freelancer
#
# [94 rows x 11 columns]

# %%
df['currency'].value_counts()
# Out:
# currency
# USD    2285
# INR    1682
# EUR     241
# GBP     164
# Name: count, dtype: int64

# %%
df['budget_type'].value_counts()
# Out:
# budget_type
# fixed_price    3402
# hourly          970
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Websites, IT & Software    4222
# Artificial Intelligence     150
# Name: count, dtype: int64

# %%
df['project_url'].value_counts()
# Out:
# project_url
# https://www.freelancer.com/projects/dot-net/all-one-travel-booking-platform                        1
# https://www.freelancer.com/projects/power-automate/power-automate-consultant-for-business          1
# https://www.freelancer.com/projects/desktop-application/employee-hours-holiday-sickness-tracker    1
# https://www.freelancer.com/projects/svg/custom-image-puzzle-generator                              1
# https://www.freelancer.com/projects/rest-api/real-time-automation-app                              1
#                                                                                                   ..
# https://www.freelancer.com/projects/machine-translation/hebrew-translation-quality-reviewer        1
# https://www.freelancer.com/projects/copywriting/logo-copywriting-poster                            1
# https://www.freelancer.com/projects/object-detection/outdoor-ultrasonic-vehicle-detection          1
# https://www.freelancer.com/projects/voice-over/speech-recording-task                               1
# https://www.freelancer.com/projects/email-handling/virtual-assistant-needed-40553154               1
# Name: count, Length: 4372, dtype: int64

# %%
print("Rows:", df.shape[0])
print("Unique URLs:", df['project_url'].nunique())
print("Duplicate URLs:", df['project_url'].duplicated().sum())

print(f"\n{df['budget_type'].value_counts()}")
print(f"\n{df['currency'].value_counts()}")
print(f"\n{df['category'].value_counts()}")
print(f"\n{df['subcategory'].value_counts()}")
# Out:
# Rows: 4372
# Unique URLs: 4372
# Duplicate URLs: 0
#
# budget_type
# fixed_price    3402
# hourly          970
# Name: count, dtype: int64
#
# currency
# USD    2285
# INR    1682
# EUR     241
# GBP     164
# Name: count, dtype: int64
#
# category
# Websites, IT & Software    4222
# Artificial Intelligence     150
# Name: count, dtype: int64
#
# subcategory
# Web Development                200
# Adobe Premiere Pro             155
# Adobe Illustrator              152
# Web Design                     122
# Social Media Management         81
#                               ...
# Music Production                 1
# Comedy Writing                   1
# Architectural Visualization      1
# Machine Translation              1
# Email Handling                   1
# Name: count, Length: 671, dtype: int64

# %%
df['skills'].apply(len).describe()
# Out:
# count    4372.000000
# mean        8.136322
# std         1.603356
# min         2.000000
# 25%         8.000000
# 50%         8.000000
# 75%        10.000000
# max        12.000000
# Name: skills, dtype: float64

# %%
df['subcategory'].value_counts()
# Out:
# subcategory
# Web Development                200
# Adobe Premiere Pro             155
# Adobe Illustrator              152
# Web Design                     122
# Social Media Management         81
#                               ...
# Music Production                 1
# Comedy Writing                   1
# Architectural Visualization      1
# Machine Translation              1
# Email Handling                   1
# Name: count, Length: 671, dtype: int64
